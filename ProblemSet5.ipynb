// %% [markdown]
// # Q5 :

// %% [markdown]
// a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False depending on whether the point (x,y) lies in the rectangle with lower left corner (x1,y1) and upper right corner (x2,y2).
// >>> inside(1,1,0,0,2,3)
// True

// %%
using System;

namespace test
{
    class Program
    {
        static void Main(string[] args)
        {
            inside(1, 1, 0, 0, 2, 3);
        }
        public static void inside(int x, int y, int x1, int y1, int x2, int y2)
        {

            if (((x > x1) & (x < x2)) & ((y > y1) & (y < y2)))
            {
                Console.WriteLine("True");
            }
            else
                Console.WriteLine("false");
        }
    }
}
// Out:
// (3,1): error CS7021: Cannot declare namespace in script code

// %% [markdown]
// ![Q5A_1-output.png](attachment:Q5A_1-output.png)

// %% [markdown]
// >>> inside(-1,-1,0,0,2,3)
// False

// %%
using System;

namespace test
{
    class Program
    {
        static void Main(string[] args)
        {
            inside(-1, -1, 0, 0, 2, 3);
        }
        public static void inside(int x, int y, int x1, int y1, int x2, int y2)
        {

            if (((x > x1) & (x < x2)) & ((y > y1) & (y < y2)))
            {
                Console.WriteLine("True");
            }
            else
                Console.WriteLine("false");
        }
    }
}

// %% [markdown]
// ![Q5A_2-output.png](attachment:Q5A_2-output.png)

// %% [markdown]
// b. Use function inside() from part a. to write an expression that tests whether the point (1,1) lies in both of the following rectangles: one with lower left corner (0.3, 0.5) and upper right corner (1.1, 0.7)

// %%
using System;

namespace test
{
    class Program
    {
        static void Main(string[] args)
        {
            inside(1, 1, 0.3f, 0.5f, 1.1f, 0.7f);
        }
        public static void inside(float x, float y, float x1, float y1, float x2, float y2)
        {

            if (((x > x1) & (x < x2)) & ((y > y1) & (y < y2)))
            {
                Console.WriteLine("True");
            }
            else
                Console.WriteLine("false");
        }
    }
}

// %% [markdown]
// ![Q5B_1-output.png](attachment:Q5B_1-output.png)

// %% [markdown]
// The other with lower left corner (0.5, 0.2) and upper right corner (1.1, 2).

// %%
using System;

namespace test
{
    class Program
    {
        static void Main(string[] args)
        {
            inside(1, 1, 0.5f, 0.2f, 1.1f, 2);
        }
        public static void inside(float x, float y, float x1, float y1, float x2, float y2)
        {

            if (((x > x1) & (x < x2)) & ((y > y1) & (y < y2)))
            {
                Console.WriteLine("True");
            }
            else
                Console.WriteLine("false");
        }
    }
}

// %% [markdown]
// ![Q5B_2-output.png](attachment:Q5B_2-output.png)
