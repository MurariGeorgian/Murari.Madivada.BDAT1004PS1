// %% [markdown]
// # Q2 :

// %% [markdown]
// Write (and evaluate) C# expressions that answer these questions:
//
// a. How many letters are there in 'Supercalifragilisticexpialidocious'?

// %%
String M = "Supercalifragilisticexpialidocious";
int count = 0;
foreach (char c in M)
{
  count++;
}
Console.WriteLine(count);
// Out:
// 34

// %% [markdown]
// b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?

// %%
string M="Supercalifragilisticexpialidocious";
if(M.Contains("ice"))
{
Console.WriteLine("Yes");
}
else
{
Console.WriteLine("No");
}
// Out:
// Yes

// %% [markdown]
// c. Which of the following words is the longest:
// Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
// Bababadalgharaghtakamminarronnkonn?

// %%
{
String strData = " Supercalifragilisticexpialidocious Honorificabilitudinitatibus Bababadalgharaghtakamminarronnkonn ";
String[] words = strData.Split(new[] { " " }, StringSplitOptions.None);
String word = "";
int tr = 0;
foreach(string M in words)
{
if (M.Length>tr)
{ word = M;
tr = M.Length;

}
}
Console.WriteLine(word);
Console.ReadLine();
}
// Out:
// Supercalifragilisticexpialidocious

// %% [markdown]
// d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
// 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

// %%
using System;

class Program
{
    static void Main()
    {
        string[] names = new string[]
        {
            "Berlioz",
            "Borodin",
            "Brian",
            "Bartok",
            "Bellini",
            "Buxtehude",
            "Bernstein"
        };
        Array.Sort(names);

        Console.WriteLine("As per dictionary the first and last composer order is:");

        foreach (string composers in names)
        {

            Console.WriteLine(composers);
        }
    }
}

// %% [markdown]
// ![Q2D-output.png](attachment:Q2D-output.png)
